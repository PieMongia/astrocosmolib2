# %%
# import alcuni pacchetti
import numpy as np
import matplotlib.pyplot as plt 
from astropy.io import fits

# %%
fits_file = "HorseHead.fits"

# %%
fits_hdu = fits.open(fits_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fits_hdu = fits.open(fits_file)
#
# File ~/anaconda3/envs/acc-env/lib/python3.12/site-packages/astropy/io/fits/hdu/hdulist.py:224, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, decompress_in_memory, **kwargs)
#     221 if not name:
#     222     raise ValueError(f"Empty filename: {name!r}")
# --> 224 return HDUList.fromfile(
#     225     name,
#     226     mode,
#     227     memmap,
#     228     save_backup,
#     229     cache,
#     230     lazy_load_hdus,
#     231     ignore_missing_simple,
#     232     use_fsspec=use_fsspec,
#     233     fsspec_kwargs=fsspec_kwargs,
#     234     decompress_in_memory=decompress_in_memory,
#     235     **kwargs,
#     236 )
#
# ...

# %%
print(fits_hdu)
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x1212cdbe0>, <astropy.io.fits.hdu.table.TableHDU object at 0x1211af1d0>]

# %%
fits_hdu.info()
# Out:
# Filename: HorseHead.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     161   (891, 893)   int16
#   1  er.mask       1 TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]

# %%
data = fits_hdu[0].data

# %%
cb = plt.imshow(data, cmap='rainbow')
plt.colorbar(cb)
plt.xlabel("X")
plt.xlabel("Y")
# Out:
# Text(0.5, 0, 'Y')
